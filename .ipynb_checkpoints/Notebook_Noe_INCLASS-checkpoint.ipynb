# %% [markdown]
# ## Paris Air BnB Data Analysis for Product Managers

# %% [markdown]
# ### Load Data and Libraries

# %% [markdown]
# We usually write in the top cell all the packages we want to import for the rest of the notebook

# %%
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# don't worry about this

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ### Load the dataset (noe_airbnb_dataset.csv)

# %%
paris_df = pd.read_csv("data/noe_airbnb_dataset.csv")

# %% [markdown]
# ### Discover the Data

# %% [markdown]
# #### 4 Basic discovering techniques

# %%
#premieres lignes
paris_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                        listing_url  \
# 0           0             0  https://www.airbnb.com/rooms/2577
# 1           1             1  https://www.airbnb.com/rooms/3109
# 2           2             2  https://www.airbnb.com/rooms/5396
# 3           3             3  https://www.airbnb.com/rooms/7397
# 4           4             4  https://www.airbnb.com/rooms/7964
#
#                                 name  \
# 0   Loft for 4 by Canal Saint Martin
# 1                       zen and calm
# 2     Explore the heart of old Paris
# 3   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 4  Large & sunny flat with balcony !
#
#                                              summary  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  Appartement très calme de 50M2 Belle lumière D...
# 2  Cozy, well-appointed and graciously designed s...
# 3          VERY CONVENIENT, WITH THE BEST LOCATION !
# 4  Very large & nice apartment all for you!  - Su...
#
#                                                space  \
# 0  The district has any service or shop you may d...
# 1                   I bedroom appartment in Paris 14
# 2  Small, well appointed studio apartment at the ...
# 3  PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...
# 4  hello ! We have a great 75 square meter apartm...
#
#                                          description experiences_offered  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...                none
# 1                   I bedroom appartment in Paris 14                none
# 2  Cozy, well-appointed and graciously designed s...                none
# 3  VERY CONVENIENT, WITH THE BEST LOCATION ! PLEA...                none
# 4  Very large & nice apartment all for you!  - Su...                none
#
#    host_id  host_since  ... longitude property_type        room_type  \
# 0     2827  2008-09-09  ...  2.362511          Loft  Entire home/apt
# 1     3631  2008-10-14  ...  2.318518     Apartment  Entire home/apt
# 2     7903  2009-02-14  ...  2.358690     Apartment  Entire home/apt
# 3     2626  2008-08-30  ...  2.352751     Apartment  Entire home/apt
# 4    22155  2009-06-18  ...  2.343411     Apartment  Entire home/apt
#
#   bathrooms bedrooms    price  cleaning_fee  minimum_nights  \
# 0       2.0      2.0  $125.00        $40.00               3
# 1       1.0      1.0   $75.00        $50.00               3
# 2       1.0      0.0  $115.00        $36.00               2
# 3       1.0      2.0  $115.00        $50.00              10
# 4       1.0      2.0   $99.00        $60.00               3
#
#   review_scores_rating reviews_per_month
# 0                  NaN               NaN
# 1                100.0              0.29
# 2                 94.0              1.29
# 3                 94.0              2.47
# 4                 96.0              0.06
#
# [5 rows x 27 columns]

# %%
#tailles
# Out:
# (59070, 27)

# %%
#les colonnes
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'listing_url', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'host_id', 'host_since',
#        'host_response_rate', 'host_neighbourhood', 'host_total_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'zipcode',
#        'latitude', 'longitude', 'property_type', 'room_type', 'bathrooms',
#        'bedrooms', 'price', 'cleaning_fee', 'minimum_nights',
#        'review_scores_rating', 'reviews_per_month'],
#       dtype='object')

# %%
#le type dans chaque colonnes

# %%
#les valeurs nulles
# Out:
# Unnamed: 0                       0
# Unnamed: 0.1                     0
# listing_url                      0
# name                            74
# summary                       2328
# space                        19028
# description                    487
# experiences_offered              0
# host_id                          0
# host_since                       8
# host_response_rate           28463
# host_neighbourhood            7930
# host_total_listings_count        8
# host_identity_verified           8
# neighbourhood_cleansed           0
# zipcode                          0
# latitude                         0
# longitude                        0
# property_type                    0
# room_type                        0
# bathrooms                       76
# bedrooms                        66
# price                            0
# cleaning_fee                 16522
# minimum_nights                   0
# review_scores_rating         13359
# reviews_per_month            12271
# dtype: int64

# %% [markdown]
# ### Clean the Data

# %% [markdown]
# ##### Drop/Fill the empty values

# %%
#na cleaning fee

# %%
#drop description na

# %%
#verify with the shape

# %% [markdown]
# ##### Keep only relevant columns

# %%
#check all columns

# %%
#drop summary, descr
columns_to_drop = ["summary","description","listing_url"]
paris_df.drop(columns_to_drop,axis="columns", inplace=True)
paris_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'name', 'space', 'experiences_offered',
#        'host_id', 'host_since', 'host_response_rate', 'host_neighbourhood',
#        'host_total_listings_count', 'host_identity_verified',
#        'neighbourhood_cleansed', 'zipcode', 'latitude', 'longitude',
#        'property_type', 'room_type', 'bathrooms', 'bedrooms', 'price',
#        'cleaning_fee', 'minimum_nights', 'review_scores_rating',
#        'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ##### Change value types

# %%
paris_df.host_response_rate = paris_df.host_response_rate.str.replace('%', '').astype(float)
paris_df['price'] = paris_df.price.str.replace('[\$\,]|\.\d*', '').astype(int)
paris_df['cleaning_fee'] = paris_df.cleaning_fee.str.replace('[\$\,]|\.\d*', '').astype(int)
paris_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               name  \
# 0           0             0   Loft for 4 by Canal Saint Martin
# 1           1             1                       zen and calm
# 2           2             2     Explore the heart of old Paris
# 3           3             3   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 4           4             4  Large & sunny flat with balcony !
#
#                                                space experiences_offered  \
# 0  The district has any service or shop you may d...                none
# 1                   I bedroom appartment in Paris 14                none
# 2  Small, well appointed studio apartment at the ...                none
# 3  PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...                none
# 4  hello ! We have a great 75 square meter apartm...                none
#
#    host_id  host_since  host_response_rate            host_neighbourhood  \
# 0     2827  2008-09-09                75.0                    République
# 1     3631  2008-10-14               100.0                        Alésia
# 2     7903  2009-02-14               100.0  Saint-Paul - Ile Saint-Louis
# 3     2626  2008-08-30               100.0                     Le Marais
# 4    22155  2009-06-18                75.0  Gare du Nord - Gare de I'Est
#
#    host_total_listings_count  ... longitude property_type        room_type  \
# 0                        2.0  ...  2.362511          Loft  Entire home/apt
# 1                        1.0  ...  2.318518     Apartment  Entire home/apt
# 2                        1.0  ...  2.358690     Apartment  Entire home/apt
# 3                        2.0  ...  2.352751     Apartment  Entire home/apt
# 4                        1.0  ...  2.343411     Apartment  Entire home/apt
#
#    bathrooms  bedrooms price cleaning_fee  minimum_nights  \
# 0        2.0       2.0   125           40               3
# 1        1.0       1.0    75           50               3
# 2        1.0       0.0   115           36               2
# 3        1.0       2.0   115           50              10
# 4        1.0       2.0    99           60               3
#
#    review_scores_rating  reviews_per_month
# 0                   NaN                NaN
# 1                 100.0               0.29
# 2                  94.0               1.29
# 3                  94.0               2.47
# 4                  96.0               0.06
#
# [5 rows x 24 columns]

# %%
paris_df.cleaning_fee.head(30)
# Out:
# 0      40
# 1      50
# 2      36
# 3      50
# 4      60
# 5       0
# 6     200
# 7      20
# 8      50
# 9      35
# 10     36
# 11      0
# 12     70
# 13      0
# 14      0
# 15     70
# 16     60
# 17     20
# 18     25
# 19     20
# 20      0
# 21     42
# 22     30
# 23     20
# 24     50
# 25     20
# 26     10
# 27     75
# 28     30
# 29    150
# Name: cleaning_fee, dtype: int64

# %% [markdown]
# ### Manipulate the Data

# %% [markdown]
# ### Select rows and columns : Create Sub Dataset

# %% [markdown]
# ##### Select Rows

# %%
# 1 row 
paris_df[1:2]
# Out:
#    Unnamed: 0  Unnamed: 0.1          name                             space  \
# 1           1             1  zen and calm  I bedroom appartment in Paris 14
#
#   experiences_offered  host_id  host_since  host_response_rate  \
# 1                none     3631  2008-10-14               100.0
#
#   host_neighbourhood  host_total_listings_count  ... longitude property_type  \
# 1             Alésia                        1.0  ...  2.318518     Apartment
#
#          room_type  bathrooms  bedrooms price cleaning_fee  minimum_nights  \
# 1  Entire home/apt        1.0       1.0    75           50               3
#
#    review_scores_rating  reviews_per_month
# 1                 100.0               0.29
#
# [1 rows x 24 columns]

# %% [markdown]
# Jusqu'au rang deux

# %%
paris_df[10:40]
# Out:
#     Unnamed: 0  Unnamed: 0.1                                          name  \
# 10          10            10                           Montmartre Studio 7
# 11          11            11                          Montmartre Studio 10
# 12          12            12           Calm  place in a "bourgeois" area !
# 13          13            13                          QUARTIER LATIN APART
# 14          14            14                                DOWNTOWN PARIS
# 15          15            15              Elegant appartment in Montmartre
# 16          16            16                 Old Paris,brand new aparment.
# 17          17            17                   Loft very charming in Paris
# 18          18            18                         Swishy Cosy Paris Pad
# 19          19            19           Faubourg Saint Antoine-chambrecalme
# 20          20            20  De Place Voltaire à Chemin vert. Paris 11ème
# 21          21            21                 Flat-bohemian SoPi Montmartre
# 22          22            22           Charming sunny 2BR in Montmartre !
# 23          23            23                      Lovely Studio Montmartre
# 24          24            24              Spacious, Light-Filled Apartment
# 25          25            25                       ***ROOFTOP LE MARAIS***
# 26          26            26                  Studio30m2 channel stmartin
# 27          27            27                           Luxury in St Michel
# 28          28            28            Charming Appartment Goncourt Paris
# 29          29            29             Your Loft / One of a kind / Paris
# 30          30            30           BEAUTIFUL APT IN PARIS CANAL ST MAR
# 31          31            31           Big Flat in Paris with a retro feel
# 32          32            32                    A Room in Paris 9e Pigalle
# 33          33            33                       Center of paris: Louvre
# 34          34            34             LOVELY  APARTMENT NEAR MONTMARTRE
# 35          35            35                     PARIS ROMANTIC MAISONETTE
# 36          36            36            TWO FLOORS apartment in Paris 5eme
# 37          37            37           LUXURIOUS PENTHOUSE+ 80 SQM TERRACE
# 38          38            38      A peaceful and very well located bedroom
# 39          39            39               LOVELY STUDIO IN QUARTIER LATIN
#
#                                                 space experiences_offered  \
# 10  The studio is an open living space measuring 2...                none
# 11  The studio has lots of natural light and has b...                none
# 12  Very close to Place de la Concorde and Madelei...                none
# 13  Description The apartment is located in the we...                none
# 14  (Description first in English then in French) ...                none
# 15  The appartment is 60 m2 large. 4th floor with ...                none
# 16  Brand new renovated studio with living room, b...                none
# 17  46 square meters It's a loft with only one roo...                none
# 18  FULLY RENOVATED THREE YEARS AGO - NON SMOKING ...                none
# 19  Chambre très claire, calme, sur le jardin dans...                none
# 20  Old french style apartment (57m2) in the heart...                none
# 21  ALWAYS MESSAGE ME BEFORE BOOKING IN ORDER TO G...                none
# 22  Beautifully furnished 1-2 bedrooms spacious ap...                none
# 23  Modern and charming studio in the butte Montma...                none
# 24  Our apartment is spacious, bright, centrally-l...                none
# 25  Very charming for 1 or 2 person (couples only,...                none
# 26  Studio30m2 channel stmartin  My studio is loca...                none
# 27  In the very heart of Paris also known as "Quar...                none
# 28  A very quiet place, rue du Faubourg du Temple,...                none
# 29  Metro: line 7 (Porte de la vilette)is less tha...                none
# 30  My beautiful spacious duplex 60 square meters ...                none
# 31  Central location in Paris. A stone's throw fro...                none
# 32  Central location in Paris. A stone's throw fro...                none
# 33  Sublimate loft in the center of Paris, 60m2, 6...                none
# 34  52m2 (560 square ft), one large living room (2...                none
# 35  AIR CONDITIONING /  STORAGE FOR YOUR LUGGAGE!!...                none
# 36  "LA CLOSERIE"  In the ground floor,  very quie...                none
# 37  This high quality and spacious penthouse is th...                none
# 38  Located in the 18th district of Paris, in the ...                none
# 39  AIR CONDITIONING  and STORAGE FOR YOUR LUGGAGE...                none
#
#     host_id  host_since  host_response_rate  \
# 10    37107  2009-09-08                86.0
# 11    37107  2009-09-08                86.0
# 12    38170  2009-09-13                80.0
# 13    40963  2009-09-24               100.0
# 14    41322  2009-09-25                90.0
# 15    41718  2009-09-28               100.0
# 16    42666  2009-10-01               100.0
# 17    44444  2009-10-08                 NaN
# 18    44626  2009-10-09               100.0
# 19    47196  2009-10-20                 NaN
# 20    48733  2009-10-28                 NaN
# 21    55023  2009-11-17               100.0
# 22    55995  2009-11-20                 NaN
# 23    57954  2009-11-27               100.0
# 24    64054  2009-12-18               100.0
# 25    64057  2009-12-18               100.0
# 26    64075  2009-12-18               100.0
# 27    64627  2009-12-20                 NaN
# 28    67010  2010-01-01               100.0
# 29    64055  2009-12-18                 NaN
# 30    67192  2010-01-02               100.0
# 31    20633  2009-06-08               100.0
# 32    20633  2009-06-08               100.0
# 33    69389  2010-01-10               100.0
# 34    71496  2010-01-18               100.0
# 35    73530  2010-01-25               100.0
# 36    73530  2010-01-25               100.0
# 37    79843  2010-02-10                80.0
# 38    80630  2010-02-12               100.0
# 39    73530  2010-01-25               100.0
#
#                    host_neighbourhood  host_total_listings_count  ...  \
# 10                         Montmartre                        4.0  ...
# 11                         Montmartre                        4.0  ...
# 12                       Saint-Lazare                        1.0  ...
# 13                           Panthéon                        2.0  ...
# 14                         République                        2.0  ...
# 15                         Montmartre                        1.0  ...
# 16                         République                        1.0  ...
# 17  Place d'Italie - Quartier Chinois                        1.0  ...
# 18                         République                        1.0  ...
# 19                  XI Arrondissement                        2.0  ...
# 20                  XI Arrondissement                        1.0  ...
# 21            Pigalle - Saint-Georges                        2.0  ...
# 22                         Montmartre                        1.0  ...
# 23                         Montmartre                        1.0  ...
# 24                         Austerlitz                        2.0  ...
# 25       Saint-Paul - Ile Saint-Louis                        2.0  ...
# 26                 Canal Saint-Martin                        1.0  ...
# 27     Saint-Germain-des-Prés - Odéon                        2.0  ...
# 28                         République                        3.0  ...
# 29                        La Villette                        1.0  ...
# 30                         République                        1.0  ...
# 31            Pigalle - Saint-Georges                        2.0  ...
# 32            Pigalle - Saint-Georges                        2.0  ...
# 33  Châtelet - Les Halles - Beaubourg                        1.0  ...
# 34                        La Chapelle                        1.0  ...
# 35                           Panthéon                        3.0  ...
# 36                           Panthéon                        3.0  ...
# 37                             Nation                       14.0  ...
# 38              Porte de Clignancourt                        1.0  ...
# 39                           Panthéon                        3.0  ...
#
#    longitude property_type        room_type  bathrooms  bedrooms price  \
# 10  2.346556     Apartment  Entire home/apt        1.0       NaN    80
# 11  2.344901     Apartment  Entire home/apt        1.0       NaN    75
# 12  2.316083     Apartment  Entire home/apt        1.0       1.0    85
# 13  2.350947     Apartment  Entire home/apt        1.0       0.0    75
# 14  2.374244     Apartment  Entire home/apt        1.0       1.0   157
# 15  2.340046     Apartment  Entire home/apt        1.0       1.0   100
# 16  2.369605     Apartment  Entire home/apt        1.0       NaN    70
# 17  2.368279          Loft  Entire home/apt        1.0       1.0   100
# 18  2.377046     Apartment  Entire home/apt        1.0       0.0    79
# 19  2.386952     Apartment     Private room        1.0       1.0    60
# 20  2.377039     Apartment  Entire home/apt        1.0       2.0    90
# 21  2.338212     Apartment  Entire home/apt        1.0       1.0    95
# 22  2.341576     Apartment  Entire home/apt        1.0       1.0   110
# 23  2.344533     Apartment  Entire home/apt        1.0       NaN    75
# 24  2.363233     Apartment  Entire home/apt        1.0       1.0    55
# 25  2.362836     Apartment  Entire home/apt        1.0       1.0    78
# 26  2.367690     Apartment  Entire home/apt        NaN       1.0    59
# 27  2.341713     Apartment     Private room        1.5       1.0   125
# 28  2.371522     Apartment  Entire home/apt        1.0       2.0   105
# 29  2.383069          Loft  Entire home/apt        2.0       1.0    89
# 30  2.362063     Apartment  Entire home/apt        1.0       1.0    80
# 31  2.332724     Apartment  Entire home/apt        1.0       2.0   110
# 32  2.332924     Apartment     Private room        1.0       1.0    65
# 33  2.342542     Apartment  Entire home/apt        1.5       1.0   250
# 34  2.359059     Apartment  Entire home/apt        1.0       1.0    80
# 35  2.352965     Apartment  Entire home/apt        1.0       1.0    98
# 36  2.354635     Apartment  Entire home/apt        2.0       1.0   120
# 37  2.400672   Condominium  Entire home/apt        1.0       2.0   190
# 38  2.335836     Apartment     Private room        1.0       1.0    55
# 39  2.354463     Apartment  Entire home/apt        1.0       0.0    98
#
#    cleaning_fee  minimum_nights  review_scores_rating  reviews_per_month
# 10           36              90                  96.0               0.38
# 11            0              30                  99.0               0.17
# 12           70               3                  88.0               0.36
# 13            0               2                  93.0               2.86
# 14            0               1                  92.0               2.58
# 15           70               5                  95.0               0.43
# 16           60               7                  94.0               0.03
# 17           20               2                  98.0               0.98
# 18           25               3                  89.0               2.98
# 19           20               6                   NaN               0.01
# 20            0               4                 100.0               1.22
# 21           42               3                  95.0               0.16
# 22           30               7                  93.0               0.10
# 23           20               3                  91.0               2.02
# 24           50               1                  90.0               0.30
# 25           20               3                  92.0               3.11
# 26           10               3                  90.0               1.09
# 27           75               5                  97.0               0.52
# 28           30               2                  87.0               0.64
# 29          150              15                  75.0               0.12
# 30           60              14                   NaN               0.23
# 31            0               2                  80.0               0.03
# 32            0               1                  94.0               0.98
# 33            0               3                  93.0               1.42
# 34            0               3                  90.0               0.02
# 35           60               3                  96.0               1.74
# 36           70               2                  95.0               1.59
# 37           50               2                  95.0               0.88
# 38            0               2                  95.0               0.67
# 39           55               2                  90.0               1.41
#
# [30 rows x 24 columns]

# %% [markdown]
# ##### Select Columns

# %%
#Select Price 
paris_df["price"]
paris_df.price

# OR
# Out:
# 0        125
# 1         75
# 2        115
# 3        115
# 4         99
#         ...
# 59065     45
# 59066     40
# 59067     58
# 59068     81
# 59069     99
# Name: price, Length: 58583, dtype: int64

# %%
paris_df[["name","price"]]
# Out:
#                                               name  price
# 0                 Loft for 4 by Canal Saint Martin    125
# 1                                     zen and calm     75
# 2                   Explore the heart of old Paris    115
# 3                 MARAIS - 2ROOMS APT - 2/4 PEOPLE    115
# 4                Large & sunny flat with balcony !     99
# ...                                            ...    ...
# 59065    Charming and Calme Studio for two Persons     45
# 59066          Studio récent 28m2 au bord de Paris     40
# 59067               Studio charme, Canal St Martin     58
# 59068  LUXURY APARTMENT - Etoile / Arc de Triomphe     81
# 59069                           Au coeur du 11ème.     99
#
# [58583 rows x 2 columns]

# %% [markdown]
# ##### Select Lines and Columns

# %%
# Select first two rows and space and price [[]]
paris_df[:2][["space","price"]]
# Out:
#                                                space  price
# 0  The district has any service or shop you may d...    125
# 1                   I bedroom appartment in Paris 14     75

# %% [markdown]
# ##### Boolean Indexing : Select with a condition

# %%
paris_df[paris_df.price <100]
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 1               1             1
# 4               4             4
# 5               5             5
# 6               6             6
# 7               7             7
# ...           ...           ...
# 59065       59876         59876
# 59066       59877         59877
# 59067       59878         59878
# 59068       59879         59879
# 59069       59880         59880
#
#                                                   name  \
# 1                                         zen and calm
# 4                    Large & sunny flat with balcony !
# 5                              GREAT FLAT w/ CITY VIEW
# 6      Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 7                            Paris petit coin douillet
# ...                                                ...
# 59065        Charming and Calme Studio for two Persons
# 59066              Studio récent 28m2 au bord de Paris
# 59067                   Studio charme, Canal St Martin
# 59068      LUXURY APARTMENT - Etoile / Arc de Triomphe
# 59069                               Au coeur du 11ème.
#
#                                                    space experiences_offered  \
# 1                       I bedroom appartment in Paris 14                none
# 4      hello ! We have a great 75 square meter apartm...                none
# 5      Really nice flat located in the 20th district ...                none
# 6      Since I live in the USA, it is difficult to ma...                none
# 7      Make your stay in Paris a perfect experience. ...                none
# ...                                                  ...                 ...
# 59065  Studio de 20m2 à proximité de l'avenue Foch da...                none
# 59066                                                NaN                none
# 59067                                                NaN                none
# 59068  At home in Paris... An incredible hideaway if ...                none
# 59069                                                NaN                none
#
#          host_id  host_since  host_response_rate  \
# 1           3631  2008-10-14               100.0
# 4          22155  2009-06-18                75.0
# 5          25435  2009-07-13                 NaN
# 6          28422  2009-07-29                86.0
# 7          33534  2009-08-24                80.0
# ...          ...         ...                 ...
# 59065   44511985  2015-09-18               100.0
# 59066  153886633  2017-10-09                 NaN
# 59067   25351458  2014-12-29                 NaN
# 59068  229551435  2018-12-07                 NaN
# 59069  229539689  2018-12-07                 NaN
#
#                       host_neighbourhood  host_total_listings_count  ...  \
# 1                                 Alésia                        1.0  ...
# 4           Gare du Nord - Gare de I'Est                        1.0  ...
# 5           Père Lachaise - Ménilmontant                        1.0  ...
# 6      Châtelet - Les Halles - Beaubourg                        3.0  ...
# 7                             République                        1.0  ...
# ...                                  ...                        ...  ...
# 59065  Châtelet - Les Halles - Beaubourg                        2.0  ...
# 59066                                NaN                        1.0  ...
# 59067                 Canal Saint-Martin                        1.0  ...
# 59068                     Champs-Elysées                        1.0  ...
# 59069                           Bastille                        2.0  ...
#
#       longitude       property_type        room_type  bathrooms  bedrooms  \
# 1      2.318518           Apartment  Entire home/apt        1.0       1.0
# 4      2.343411           Apartment  Entire home/apt        1.0       2.0
# 5      2.393263           Apartment  Entire home/apt        1.0       1.0
# 6      2.347347           Apartment  Entire home/apt        1.0       1.0
# 7      2.371341           Apartment  Entire home/apt        1.0       1.0
# ...         ...                 ...              ...        ...       ...
# 59065  2.281544  Serviced apartment  Entire home/apt        1.0       0.0
# 59066  2.330878           Apartment  Entire home/apt        1.0       0.0
# 59067  2.366238           Apartment  Entire home/apt        1.0       0.0
# 59068  2.289126           Apartment  Entire home/apt        1.0       1.0
# 59069  2.381328           Apartment  Entire home/apt        1.0       0.0
#
#       price cleaning_fee  minimum_nights  review_scores_rating  \
# 1        75           50               3                 100.0
# 4        99           60               3                  96.0
# 5        90            0               3                 100.0
# 6        75          200             180                   NaN
# 7        70           20               5                  99.0
# ...     ...          ...             ...                   ...
# 59065    45           50              30                   NaN
# 59066    40            0               1                   NaN
# 59067    58            0               2                   NaN
# 59068    81           60               2                   NaN
# 59069    99            0               1                   NaN
#
#        reviews_per_month
# 1                   0.29
# 4                   0.06
# 5                   0.01
# 6                    NaN
# 7                   0.24
# ...                  ...
# 59065                NaN
# 59066               1.00
# 59067                NaN
# 59068                NaN
# 59069                NaN
#
# [38838 rows x 24 columns]

# %%
paris_df[paris_df['host_response_rate'] > 75]
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 1               1             1
# 2               2             2
# 3               3             3
# 6               6             6
# 7               7             7
# ...           ...           ...
# 59043       59854         59854
# 59055       59866         59866
# 59063       59874         59874
# 59064       59875         59875
# 59065       59876         59876
#
#                                                   name  \
# 1                                         zen and calm
# 2                       Explore the heart of old Paris
# 3                     MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 6      Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 7                            Paris petit coin douillet
# ...                                                ...
# 59043                         paris la place de clichy
# 59055                           studio aux batignolles
# 59063  Functionnal & Cosy Flat In Northern Paris For 4
# 59064      Beautiful Top floor studio/Sacre Coeur view
# 59065        Charming and Calme Studio for two Persons
#
#                                                    space experiences_offered  \
# 1                       I bedroom appartment in Paris 14                none
# 2      Small, well appointed studio apartment at the ...                none
# 3      PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...                none
# 6      Since I live in the USA, it is difficult to ma...                none
# 7      Make your stay in Paris a perfect experience. ...                none
# ...                                                  ...                 ...
# 59043                                                NaN                none
# 59055                                                NaN                none
# 59063  1) What is so cool about the flat:  - very wel...                none
# 59064  Welcome to my flat in the eart of Montmartre, ...                none
# 59065  Studio de 20m2 à proximité de l'avenue Foch da...                none
#
#          host_id  host_since  host_response_rate  \
# 1           3631  2008-10-14               100.0
# 2           7903  2009-02-14               100.0
# 3           2626  2008-08-30               100.0
# 6          28422  2009-07-29                86.0
# 7          33534  2009-08-24                80.0
# ...          ...         ...                 ...
# 59043  220595237  2018-10-14                90.0
# 59055  141819329  2017-07-22               100.0
# 59063   34684410  2015-05-31               100.0
# 59064    5316302  2013-03-04               100.0
# 59065   44511985  2015-09-18               100.0
#
#                       host_neighbourhood  host_total_listings_count  ...  \
# 1                                 Alésia                        1.0  ...
# 2           Saint-Paul - Ile Saint-Louis                        1.0  ...
# 3                              Le Marais                        2.0  ...
# 6      Châtelet - Les Halles - Beaubourg                        3.0  ...
# 7                             République                        1.0  ...
# ...                                  ...                        ...  ...
# 59043                       Saint-Lazare                        2.0  ...
# 59055                        Batignolles                        2.0  ...
# 59063                              Passy                       33.0  ...
# 59064                         Montmartre                        2.0  ...
# 59065  Châtelet - Les Halles - Beaubourg                        2.0  ...
#
#       longitude       property_type        room_type  bathrooms  bedrooms  \
# 1      2.318518           Apartment  Entire home/apt        1.0       1.0
# 2      2.358690           Apartment  Entire home/apt        1.0       0.0
# 3      2.352751           Apartment  Entire home/apt        1.0       2.0
# 6      2.347347           Apartment  Entire home/apt        1.0       1.0
# 7      2.371341           Apartment  Entire home/apt        1.0       1.0
# ...         ...                 ...              ...        ...       ...
# 59043  2.326580           Apartment  Entire home/apt        0.5       0.0
# 59055  2.323067           Apartment  Entire home/apt        1.0       1.0
# 59063  2.360979           Apartment  Entire home/apt        1.0       1.0
# 59064  2.346018                Loft  Entire home/apt        1.0       1.0
# 59065  2.281544  Serviced apartment  Entire home/apt        1.0       0.0
#
#       price cleaning_fee  minimum_nights  review_scores_rating  \
# 1        75           50               3                 100.0
# 2       115           36               2                  94.0
# 3       115           50              10                  94.0
# 6        75          200             180                   NaN
# 7        70           20               5                  99.0
# ...     ...          ...             ...                   ...
# 59043    34           10               4                   NaN
# 59055   110            0               2                   NaN
# 59063   111           39               1                   NaN
# 59064   100           30               2                   NaN
# 59065    45           50              30                   NaN
#
#        reviews_per_month
# 1                   0.29
# 2                   1.29
# 3                   2.47
# 6                    NaN
# 7                   0.24
# ...                  ...
# 59043                NaN
# 59055                NaN
# 59063                NaN
# 59064                NaN
# 59065                NaN
#
# [26684 rows x 24 columns]

# %% [markdown]
# #### Create a new column

# %% [markdown]
#  Let's say as a PM you are interested in having a closer look to luxury listings. A better way to display apartment price is just to list an apartment as : Affordable Or Expensive. So let's create a column called : price_category

# %%
paris_df.loc[paris_df["price"] > 300, "price_category"] = 'Expensive'
paris_df.loc[paris_df["price"] <= 300, "price_category"] = 'Affordable'
paris_df.loc[paris_df["cleaning_fee"] > 0, "has_cleaning_fee"] = "yes"
paris_df.loc[paris_df["cleaning_fee"] == 0, "has_cleaning_fee"] = "no"

# %%
paris_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'name', 'space', 'experiences_offered',
#        'host_id', 'host_since', 'host_response_rate', 'host_neighbourhood',
#        'host_total_listings_count', 'host_identity_verified',
#        'neighbourhood_cleansed', 'zipcode', 'latitude', 'longitude',
#        'property_type', 'room_type', 'bathrooms', 'bedrooms', 'price',
#        'cleaning_fee', 'minimum_nights', 'review_scores_rating',
#        'reviews_per_month', 'price_category', 'has_cleaning_fee'],
#       dtype='object')

# %% [markdown]
# There is an other obvious column that we should have created. Can you see it ?

# %% [markdown]
# ### Business Questions

# %% [markdown]
# #### What is the mean and median price of a listing in Paris  ❓

# %%
paris_df.price.median()
# Out:
# 80.0

# %%
paris_df.price.mean()
# Out:
# 110.86477305703019

# %% [markdown]
# #### How many listings have a cleaning fee ❓

# %%
paris_df.price_category.value_counts()
# Out:
# Affordable    56493
# Expensive      2090
# Name: price_category, dtype: int64

# %% [markdown]
# #### What is the average rating for expensive and affordable listings   ❓

# %%
affordable = paris_df[paris_df.price_category == "Affordable"]
expensive = paris_df[paris_df.price_category == "Expensive"]

# %%
affordable.review_scores_rating.mean()
# Out:
# 92.79593267882188

# %%
expensive.review_scores_rating.mean()
# Out:
# 94.20449077786688

# %% [markdown]
# #### What are the best reviewed listings  (with minimum 3 reviews per months) ❓

# %%
reviewed_listings = paris_df[paris_df['reviews_per_month'] > 3]
reviewed_listings.nlargest(10,'review_scores_rating')
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 2802         2811          2811
# 4964         5001          5001
# 5228         5270          5270
# 5535         5587          5587
# 5764         5818          5818
# 10895       10993         10993
# 11487       11591         11591
# 11885       11991         11991
# 14122       14244         14244
# 16386       16525         16525
#
#                                                     name  \
# 2802     Paris Tour Eiffel 15e Appartement 2 pièces 50m2
# 4964                  2Pièces Duplex 54m2 +Terrasse 20m2
# 5228   Paris Montmartre : Jolie chambre sur cour fleurie
# 5535                 NOTRE DAME:bright, elegant apt 2 BR
# 5764   Quiet / Bright apt btwn Buttes Chaumont & Jour...
# 10895         Studio lumineux et calme, Paris Belleville
# 11487                                          cosy room
# 11885                Appartement cosy au coeur de Paris.
# 14122                        THE BEST DEAL IN THE MARAIS
# 16386           Appartement 55 m2 en plein coeur Paris !
#
#                                                    space experiences_offered  \
# 2802   Appartement 2 pièces de 50m² avec une petite t...                none
# 4964   Appartement type loft disposant de 2 pièces en...                none
# 5228                                                 NaN                none
# 5535   The space: This apartment is designed to comfo...                none
# 5764   This flat for 3 people, is located in 19th dis...                none
# 10895  Ce studio est pratique, spacieux et calme. Il ...                none
# 11487                                                NaN                none
# 11885  Appartement deux pièces chambre et salon, avec...                none
# 14122  If you want to get the local feeling of living...                none
# 16386  Logement spacieux avec balcon dans bel immeubl...                none
#
#         host_id  host_since  host_response_rate            host_neighbourhood  \
# 2802    6667881  2013-05-31                 NaN   Tour Eiffel - Champ de Mars
# 4964   12421039  2014-02-20               100.0  Buttes-Chaumont - Belleville
# 5228   13430813  2014-03-23                80.0                    Montmartre
# 5535    1801963  2012-02-24               100.0   Notre Dame - Ile de La Cité
# 5764   15087229  2014-05-04                 NaN  Buttes-Chaumont - Belleville
# 10895  29382043  2015-03-15                80.0                    République
# 11487  31590660  2015-04-20               100.0  Père Lachaise - Ménilmontant
# 11885  15301422  2014-05-09               100.0  Buttes-Chaumont - Belleville
# 14122   5815201  2013-04-07               100.0            III Arrondissement
# 16386   7852785  2013-07-31               100.0              X Arrondissement
#
#        host_total_listings_count  ...        room_type bathrooms  bedrooms  \
# 2802                         1.0  ...  Entire home/apt       1.0       1.0
# 4964                         1.0  ...  Entire home/apt       1.0       1.0
# 5228                         1.0  ...     Private room       1.0       1.0
# 5535                         1.0  ...  Entire home/apt       1.0       2.0
# 5764                         1.0  ...  Entire home/apt       1.0       1.0
# 10895                        1.0  ...  Entire home/apt       1.0       0.0
# 11487                        3.0  ...     Private room       1.5       1.0
# 11885                        1.0  ...  Entire home/apt       1.0       1.0
# 14122                        1.0  ...  Entire home/apt       1.0       1.0
# 16386                        1.0  ...  Entire home/apt       1.0       1.0
#
#        price  cleaning_fee minimum_nights review_scores_rating  \
# 2802      90             0              2                100.0
# 4964      95             0              2                100.0
# 5228      60             5              1                100.0
# 5535     300           110              5                100.0
# 5764      80            60              2                100.0
# 10895     60            20              3                100.0
# 11487     40            15              1                100.0
# 11885     80             0              2                100.0
# 14122     90            40              1                100.0
# 16386     95             0              3                100.0
#
#        reviews_per_month  price_category  has_cleaning_fee
# 2802                3.13      Affordable                no
# 4964                4.03      Affordable                no
# 5228                3.70      Affordable               yes
# 5535                3.16      Affordable               yes
# 5764                3.59      Affordable               yes
# 10895               3.05      Affordable               yes
# 11487               3.56      Affordable               yes
# 11885               6.00      Affordable                no
# 14122               3.43      Affordable               yes
# 16386               3.33      Affordable                no
#
# [10 rows x 26 columns]

# %% [markdown]
# ### Visualize Data

# %% [markdown]
# #### What are arrondissement with most listings ❓

# %%
plt.figure(figsize=(15, 8))
paris_df.zipcode.value_counts().head(10).plot(kind='bar')

# %% [markdown]
# That's not very nice...

# %%
paris_df.zipcode.value_counts().head(15).plot(kind='bar')

# %%
paris_df.zipcode.value_counts().tail(15).plot(kind='bar')

# %% [markdown]
# #### What is the share of expensive listings for arr. with most listings ❓

# %%
plt.figure(figsize=(15, 8))
my_order = paris_df.zipcode.value_counts().head(10).index
sns.countplot(data=paris_df,x="zipcode",hue="price_category",order=my_order)

# %% [markdown]
# #### [Distribution] What is the distribution of listings' price  ❓

# %%
plt.figure(figsize=(15, 8))
sns.distplot(affordable['price'])

# %%
affordable_listings_df = paris_df[paris_df['price'] <= 300]
sns.distplot(affordable_listings_df['price'])
plt.title('Graph Title')
plt.ylabel('%')
# Out:
# Text(0, 0.5, '%')

# %% [markdown]
# #### Violin Plot

# %% [markdown]
# #### What is the price distribution for each arrondissement ❓

# %%
plt.figure(figsize=(15, 8))
order = paris_df.zipcode.value_counts().head(10).index
sns.violinplot(data=affordable_listings_df, x="zipcode", y="price", order=order)

# %% [markdown]
# ##### Let's see the geography of listings

# %%
paris_df.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(15,8))

# %% [markdown]
# Why is everything Black ?

# %%
affordable.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(15,8))
