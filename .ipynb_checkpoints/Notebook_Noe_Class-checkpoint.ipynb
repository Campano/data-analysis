# %% [markdown]
# ### Paris Air BnB Data Analysis for Product Managers

# %% [markdown]
# ### 1️⃣ Load Data and Packages

# %% [markdown]
# We usually write in the top cell all the packages we want to import for the rest of the notebook

# %% [markdown]
# **Import relevant packages**

# %%
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# **Don't worry about this cell right here 👇**

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# **Loading the data**

# %%
#Loading the df and checking what type it is
paris_df = pd.read_csv("data/noe_airbnb_dataset.csv")
type(paris_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 2️⃣ Discover the Data

# %% [markdown]
# #### 5 Basic discovering techniques

# %%
#premieres lignes
paris_df.head(5)
# Out:
#                          listing_url                               name  \
# 0  https://www.airbnb.com/rooms/2577   Loft for 4 by Canal Saint Martin
# 1  https://www.airbnb.com/rooms/3109                       zen and calm
# 2  https://www.airbnb.com/rooms/5396     Explore the heart of old Paris
# 3  https://www.airbnb.com/rooms/7397   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 4  https://www.airbnb.com/rooms/7964  Large & sunny flat with balcony !
#
#                                              summary  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  Appartement très calme de 50M2 Belle lumière D...
# 2  Cozy, well-appointed and graciously designed s...
# 3          VERY CONVENIENT, WITH THE BEST LOCATION !
# 4  Very large & nice apartment all for you!  - Su...
#
#                                                space  \
# 0  The district has any service or shop you may d...
# 1                   I bedroom appartment in Paris 14
# 2  Small, well appointed studio apartment at the ...
# 3  PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...
# 4  hello ! We have a great 75 square meter apartm...
#
#                                          description experiences_offered  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...                none
# 1                   I bedroom appartment in Paris 14                none
# 2  Cozy, well-appointed and graciously designed s...                none
# 3  VERY CONVENIENT, WITH THE BEST LOCATION ! PLEA...                none
# 4  Very large & nice apartment all for you!  - Su...                none
#
#    host_id  host_since host_response_rate            host_neighbourhood  ...  \
# 0     2827  2008-09-09                75%                    République  ...
# 1     3631  2008-10-14               100%                        Alésia  ...
# 2     7903  2009-02-14               100%  Saint-Paul - Ile Saint-Louis  ...
# 3     2626  2008-08-30               100%                     Le Marais  ...
# 4    22155  2009-06-18                75%  Gare du Nord - Gare de I'Est  ...
#
#    longitude property_type        room_type  bathrooms  bedrooms  price  \
# 0   2.362511          Loft  Entire home/apt        2.0       2.0    125
# 1   2.318518     Apartment  Entire home/apt        1.0       1.0     75
# 2   2.358690     Apartment  Entire home/apt        1.0       0.0    115
# 3   2.352751     Apartment  Entire home/apt        1.0       2.0    115
# 4   2.343411     Apartment  Entire home/apt        1.0       2.0     99
#
#   cleaning_fee minimum_nights  review_scores_rating  reviews_per_month
# 0           40              3                   NaN                NaN
# 1           50              3                 100.0               0.29
# 2           36              2                  94.0               1.29
# 3           50             10                  94.0               2.47
# 4           60              3                  96.0               0.06
#
# [5 rows x 25 columns]

# %%
#taille du dataset
paris_df.shape
# Out:
# (59070, 25)

# %%
#les colonnes 
paris_df.columns
# Out:
# Index(['listing_url', 'name', 'summary', 'space', 'description',
#        'experiences_offered', 'host_id', 'host_since', 'host_response_rate',
#        'host_neighbourhood', 'host_total_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'zipcode',
#        'latitude', 'longitude', 'property_type', 'room_type', 'bathrooms',
#        'bedrooms', 'price', 'cleaning_fee', 'minimum_nights',
#        'review_scores_rating', 'reviews_per_month'],
#       dtype='object')

# %%
#le type dans chaque colonnes
paris_df.dtypes
# Out:
# listing_url                   object
# name                          object
# summary                       object
# space                         object
# description                   object
# experiences_offered           object
# host_id                        int64
# host_since                    object
# host_response_rate            object
# host_neighbourhood            object
# host_total_listings_count    float64
# host_identity_verified        object
# neighbourhood_cleansed        object
# zipcode                        int64
# latitude                     float64
# longitude                    float64
# property_type                 object
# room_type                     object
# bathrooms                    float64
# bedrooms                     float64
# price                          int64
# cleaning_fee                   int64
# minimum_nights                 int64
# review_scores_rating         float64
# reviews_per_month            float64
# dtype: object

# %%
#les valeurs nulles
paris_df.isnull().sum()
# Out:
# listing_url                      0
# name                            74
# summary                       2328
# space                        19028
# description                    487
# experiences_offered              0
# host_id                          0
# host_since                       8
# host_response_rate           28463
# host_neighbourhood            7930
# host_total_listings_count        8
# host_identity_verified           8
# neighbourhood_cleansed           0
# zipcode                          0
# latitude                         0
# longitude                        0
# property_type                    0
# room_type                        0
# bathrooms                       76
# bedrooms                        66
# price                            0
# cleaning_fee                     0
# minimum_nights                   0
# review_scores_rating         13359
# reviews_per_month            12271
# dtype: int64

# %% [markdown]
# ### 0️⃣ Manipulate the Data

# %% [markdown]
# ### Select rows and columns : Create Sub Dataset

# %% [markdown]
# ##### Select Rows

# %%
# 1 row 
paris_df[1:2]
# Out:
#                          listing_url          name  \
# 1  https://www.airbnb.com/rooms/3109  zen and calm
#
#                                              summary  \
# 1  Appartement très calme de 50M2 Belle lumière D...
#
#                               space                       description  \
# 1  I bedroom appartment in Paris 14  I bedroom appartment in Paris 14
#
#   experiences_offered  host_id  host_since host_response_rate  \
# 1                none     3631  2008-10-14               100%
#
#   host_neighbourhood  ...  longitude property_type        room_type  \
# 1             Alésia  ...   2.318518     Apartment  Entire home/apt
#
#    bathrooms  bedrooms  price cleaning_fee minimum_nights  \
# 1        1.0       1.0     75           50              3
#
#    review_scores_rating  reviews_per_month
# 1                 100.0               0.29
#
# [1 rows x 25 columns]

# %%
#Du row 10 au 20
paris_df[10:20]
# Out:
#                            listing_url                                 name  \
# 10  https://www.airbnb.com/rooms/10586                  Montmartre Studio 7
# 11  https://www.airbnb.com/rooms/10588                 Montmartre Studio 10
# 12  https://www.airbnb.com/rooms/10710  Calm  place in a "bourgeois" area !
# 13  https://www.airbnb.com/rooms/11170                 QUARTIER LATIN APART
# 14  https://www.airbnb.com/rooms/11213                       DOWNTOWN PARIS
# 15  https://www.airbnb.com/rooms/11265     Elegant appartment in Montmartre
# 16  https://www.airbnb.com/rooms/11487        Old Paris,brand new aparment.
# 17  https://www.airbnb.com/rooms/11798          Loft very charming in Paris
# 18  https://www.airbnb.com/rooms/11848                Swishy Cosy Paris Pad
# 19  https://www.airbnb.com/rooms/12268  Faubourg Saint Antoine-chambrecalme
#
#                                               summary  \
# 10  LONG TERM RENTAL Available  The studio is situ...
# 11  LONG TERM RENTAL 12 MONTHS  - 9 MONTHS for STU...
# 12                                                NaN
# 13                                                NaN
# 14  Numéro d'enregistrement Ville de Paris (Phone ...
# 15  Located in lively and charming Montmartre, in ...
# 16                                                NaN
# 17  Mon appartement est situé dans une très jolie ...
# 18  ***SWISHY COSY PAD*** The apartment is on the ...
# 19                                                NaN
#
#                                                 space  \
# 10  The studio is an open living space measuring 2...
# 11  The studio has lots of natural light and has b...
# 12  Very close to Place de la Concorde and Madelei...
# 13  Description The apartment is located in the we...
# 14  (Description first in English then in French) ...
# 15  The appartment is 60 m2 large. 4th floor with ...
# 16  Brand new renovated studio with living room, b...
# 17  46 square meters It's a loft with only one roo...
# 18  FULLY RENOVATED THREE YEARS AGO - NON SMOKING ...
# 19  Chambre très claire, calme, sur le jardin dans...
#
#                                           description experiences_offered  \
# 10  LONG TERM RENTAL Available  The studio is situ...                none
# 11  LONG TERM RENTAL 12 MONTHS  - 9 MONTHS for STU...                none
# 12  Very close to Place de la Concorde and Madelei...                none
# 13  Description The apartment is located in the we...                none
# 14  Numéro d'enregistrement Ville de Paris (Phone ...                none
# 15  Located in lively and charming Montmartre, in ...                none
# 16  Brand new renovated studio with living room, b...                none
# 17  Mon appartement est situé dans une très jolie ...                none
# 18  FULLY RENOVATED THREE YEARS AGO - NON SMOKING ...                none
# 19  Chambre très claire, calme, sur le jardin dans...                none
#
#     host_id  host_since host_response_rate                 host_neighbourhood  \
# 10    37107  2009-09-08                86%                         Montmartre
# 11    37107  2009-09-08                86%                         Montmartre
# 12    38170  2009-09-13                80%                       Saint-Lazare
# 13    40963  2009-09-24               100%                           Panthéon
# 14    41322  2009-09-25                90%                         République
# 15    41718  2009-09-28               100%                         Montmartre
# 16    42666  2009-10-01               100%                         République
# 17    44444  2009-10-08                NaN  Place d'Italie - Quartier Chinois
# 18    44626  2009-10-09               100%                         République
# 19    47196  2009-10-20                NaN                  XI Arrondissement
#
#     ...  longitude property_type        room_type  bathrooms  bedrooms  price  \
# 10  ...   2.346556     Apartment  Entire home/apt        1.0       NaN     80
# 11  ...   2.344901     Apartment  Entire home/apt        1.0       NaN     75
# 12  ...   2.316083     Apartment  Entire home/apt        1.0       1.0     85
# 13  ...   2.350947     Apartment  Entire home/apt        1.0       0.0     75
# 14  ...   2.374244     Apartment  Entire home/apt        1.0       1.0    157
# 15  ...   2.340046     Apartment  Entire home/apt        1.0       1.0    100
# 16  ...   2.369605     Apartment  Entire home/apt        1.0       NaN     70
# 17  ...   2.368279          Loft  Entire home/apt        1.0       1.0    100
# 18  ...   2.377046     Apartment  Entire home/apt        1.0       0.0     79
# 19  ...   2.386952     Apartment     Private room        1.0       1.0     60
#
#    cleaning_fee minimum_nights  review_scores_rating  reviews_per_month
# 10           36             90                  96.0               0.38
# 11            0             30                  99.0               0.17
# 12           70              3                  88.0               0.36
# 13            0              2                  93.0               2.86
# 14            0              1                  92.0               2.58
# 15           70              5                  95.0               0.43
# 16           60              7                  94.0               0.03
# 17           20              2                  98.0               0.98
# 18           25              3                  89.0               2.98
# 19           20              6                   NaN               0.01
#
# [10 rows x 25 columns]

# %% [markdown]
# ##### Select Columns

# %%
#Select Price 
paris_df["price"]
# OR 
paris_df.price
# Out:
# 0        125
# 1         75
# 2        115
# 3        115
# 4         99
#         ...
# 59065     45
# 59066     40
# 59067     58
# 59068     81
# 59069     99
# Name: price, Length: 59070, dtype: int64

# %%
#Select name and price
paris_df[["name","price"]]
# Out:
#                                               name  price
# 0                 Loft for 4 by Canal Saint Martin    125
# 1                                     zen and calm     75
# 2                   Explore the heart of old Paris    115
# 3                 MARAIS - 2ROOMS APT - 2/4 PEOPLE    115
# 4                Large & sunny flat with balcony !     99
# ...                                            ...    ...
# 59065    Charming and Calme Studio for two Persons     45
# 59066          Studio récent 28m2 au bord de Paris     40
# 59067               Studio charme, Canal St Martin     58
# 59068  LUXURY APARTMENT - Etoile / Arc de Triomphe     81
# 59069                           Au coeur du 11ème.     99
#
# [59070 rows x 2 columns]

# %% [markdown]
# ##### Select Lines and Columns

# %%
# Select first two rows and space and price [[]]
paris_df[:2][["space","price"]]
# Out:
#                                                space  price
# 0  The district has any service or shop you may d...    125
# 1                   I bedroom appartment in Paris 14     75

# %% [markdown]
# ##### Boolean Indexing : Select with a condition

# %%
#create a dataframe with only listings that cost less than 100$
paris_df[paris_df.price <100]
# Out:
#                                  listing_url  \
# 1          https://www.airbnb.com/rooms/3109
# 4          https://www.airbnb.com/rooms/7964
# 5          https://www.airbnb.com/rooms/8522
# 6          https://www.airbnb.com/rooms/9359
# 7          https://www.airbnb.com/rooms/9952
# ...                                      ...
# 59065  https://www.airbnb.com/rooms/30621199
# 59066  https://www.airbnb.com/rooms/30627500
# 59067  https://www.airbnb.com/rooms/30630615
# 59068  https://www.airbnb.com/rooms/30637928
# 59069  https://www.airbnb.com/rooms/30638025
#
#                                                   name  \
# 1                                         zen and calm
# 4                    Large & sunny flat with balcony !
# 5                              GREAT FLAT w/ CITY VIEW
# 6      Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 7                            Paris petit coin douillet
# ...                                                ...
# 59065        Charming and Calme Studio for two Persons
# 59066              Studio récent 28m2 au bord de Paris
# 59067                   Studio charme, Canal St Martin
# 59068      LUXURY APARTMENT - Etoile / Arc de Triomphe
# 59069                               Au coeur du 11ème.
#
#                                                  summary  \
# 1      Appartement très calme de 50M2 Belle lumière D...
# 4      Very large & nice apartment all for you!  - Su...
# 5                                                    NaN
# 6      Location! Location! Location! Just bring your ...
# 7                                                    NaN
# ...                                                  ...
# 59065  20m2 studio near avenue Foch in a very quiet s...
# 59066  Charmant studio de 28m2 dans un quartier neuf ...
# 59067  Studio chaleureux situé sur le canal St Martin...
# 59068  Luxury fully-renovated Apartment,  in a beauti...
# 59069                                   Studio au calme.
#
#                                                    space  \
# 1                       I bedroom appartment in Paris 14
# 4      hello ! We have a great 75 square meter apartm...
# 5      Really nice flat located in the 20th district ...
# 6      Since I live in the USA, it is difficult to ma...
# 7      Make your stay in Paris a perfect experience. ...
# ...                                                  ...
# 59065  Studio de 20m2 à proximité de l'avenue Foch da...
# 59066                                                NaN
# 59067                                                NaN
# 59068  At home in Paris... An incredible hideaway if ...
# 59069                                                NaN
#
#                                              description experiences_offered  \
# 1                       I bedroom appartment in Paris 14                none
# 4      Very large & nice apartment all for you!  - Su...                none
# 5      Really nice flat located in the 20th district ...                none
# 6      Location! Location! Location! Just bring your ...                none
# 7      Make your stay in Paris a perfect experience. ...                none
# ...                                                  ...                 ...
# 59065  20m2 studio near avenue Foch in a very quiet s...                none
# 59066  Charmant studio de 28m2 dans un quartier neuf ...                none
# 59067  Studio chaleureux situé sur le canal St Martin...                none
# 59068  Luxury fully-renovated Apartment,  in a beauti...                none
# 59069                                   Studio au calme.                none
#
#          host_id  host_since host_response_rate  \
# 1           3631  2008-10-14               100%
# 4          22155  2009-06-18                75%
# 5          25435  2009-07-13                NaN
# 6          28422  2009-07-29                86%
# 7          33534  2009-08-24                80%
# ...          ...         ...                ...
# 59065   44511985  2015-09-18               100%
# 59066  153886633  2017-10-09                NaN
# 59067   25351458  2014-12-29                NaN
# 59068  229551435  2018-12-07                NaN
# 59069  229539689  2018-12-07                NaN
#
#                       host_neighbourhood  ...  longitude       property_type  \
# 1                                 Alésia  ...   2.318518           Apartment
# 4           Gare du Nord - Gare de I'Est  ...   2.343411           Apartment
# 5           Père Lachaise - Ménilmontant  ...   2.393263           Apartment
# 6      Châtelet - Les Halles - Beaubourg  ...   2.347347           Apartment
# 7                             République  ...   2.371341           Apartment
# ...                                  ...  ...        ...                 ...
# 59065  Châtelet - Les Halles - Beaubourg  ...   2.281544  Serviced apartment
# 59066                                NaN  ...   2.330878           Apartment
# 59067                 Canal Saint-Martin  ...   2.366238           Apartment
# 59068                     Champs-Elysées  ...   2.289126           Apartment
# 59069                           Bastille  ...   2.381328           Apartment
#
#              room_type  bathrooms  bedrooms  price cleaning_fee  \
# 1      Entire home/apt        1.0       1.0     75           50
# 4      Entire home/apt        1.0       2.0     99           60
# 5      Entire home/apt        1.0       1.0     90            0
# 6      Entire home/apt        1.0       1.0     75          200
# 7      Entire home/apt        1.0       1.0     70           20
# ...                ...        ...       ...    ...          ...
# 59065  Entire home/apt        1.0       0.0     45           50
# 59066  Entire home/apt        1.0       0.0     40            0
# 59067  Entire home/apt        1.0       0.0     58            0
# 59068  Entire home/apt        1.0       1.0     81           60
# 59069  Entire home/apt        1.0       0.0     99            0
#
#       minimum_nights  review_scores_rating  reviews_per_month
# 1                  3                 100.0               0.29
# 4                  3                  96.0               0.06
# 5                  3                 100.0               0.01
# 6                180                   NaN                NaN
# 7                  5                  99.0               0.24
# ...              ...                   ...                ...
# 59065             30                   NaN                NaN
# 59066              1                   NaN               1.00
# 59067              2                   NaN                NaN
# 59068              2                   NaN                NaN
# 59069              1                   NaN                NaN
#
# [39166 rows x 25 columns]

# %% [markdown]
# #### Create a new column

# %% [markdown]
# We want to create a new column named **full_price** that takes into account the price of the listing + the cleaning fee

# %%
paris_df["full_price"] = paris_df["price"] + paris_df["cleaning_fee"]

# %% [markdown]
# #### Create a new column with a condition (.loc)

# %% [markdown]
#  Let's say as a PM you are interested in having a closer look to luxury listings. A better way to display apartment price is just to list an apartment as : Affordable Or Expensive. So let's create a column called : **price_category**
#
#  If the price is more than 300 then the listing is "Expensive" otherwise it is affordable

# %%
paris_df.loc[paris_df["price"] > 300, "price_category"] = 'Expensive'
paris_df.loc[paris_df["price"] <= 300, "price_category"] = 'Affordable'

# %%
paris_df.columns
# Out:
# Index(['listing_url', 'name', 'summary', 'space', 'description',
#        'experiences_offered', 'host_id', 'host_since', 'host_response_rate',
#        'host_neighbourhood', 'host_total_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'zipcode',
#        'latitude', 'longitude', 'property_type', 'room_type', 'bathrooms',
#        'bedrooms', 'price', 'cleaning_fee', 'minimum_nights',
#        'review_scores_rating', 'reviews_per_month', 'full_price',
#        'price_category'],
#       dtype='object')

# %% [markdown]
# ###  3️⃣ Clean the Data

# %% [markdown]
# ##### Drop/Fill the empty values

# %%
#fill the missing host_response_rate with "0%" 
paris_df["host_response_rate"].fillna("0%",inplace=True)

# %%
#drop the listings with no description
paris_df.dropna(subset = ["description"], inplace=True)

# %%
#checking again the size to see if it has got smaller
paris_df.shape
# Out:
# (58583, 27)

# %% [markdown]
# ##### Keep only relevant columns

# %%
#check the columns
paris_df.columns
# Out:
# Index(['listing_url', 'name', 'summary', 'space', 'description',
#        'experiences_offered', 'host_id', 'host_since', 'host_response_rate',
#        'host_neighbourhood', 'host_total_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'zipcode',
#        'latitude', 'longitude', 'property_type', 'room_type', 'bathrooms',
#        'bedrooms', 'price', 'cleaning_fee', 'minimum_nights',
#        'review_scores_rating', 'reviews_per_month', 'full_price',
#        'price_category'],
#       dtype='object')

# %%
#drop summary, description and listing_url
columns_to_drop = ["summary","description","listing_url"]
paris_df.drop(columns_to_drop,axis="columns", inplace=True)
paris_df.columns
# Out:
# Index(['name', 'space', 'experiences_offered', 'host_id', 'host_since',
#        'host_response_rate', 'host_neighbourhood', 'host_total_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'zipcode',
#        'latitude', 'longitude', 'property_type', 'room_type', 'bathrooms',
#        'bedrooms', 'price', 'cleaning_fee', 'minimum_nights',
#        'review_scores_rating', 'reviews_per_month', 'full_price',
#        'price_category'],
#       dtype='object')

# %% [markdown]
# ##### Change value types

# %%
#change response rate to float
paris_df.host_response_rate = paris_df.host_response_rate.str.replace('%', '').astype(float)

#check if changes were indeed made
paris_df.head(5)
# Out:
#                                 name  \
# 0   Loft for 4 by Canal Saint Martin
# 1                       zen and calm
# 2     Explore the heart of old Paris
# 3   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 4  Large & sunny flat with balcony !
#
#                                                space experiences_offered  \
# 0  The district has any service or shop you may d...                none
# 1                   I bedroom appartment in Paris 14                none
# 2  Small, well appointed studio apartment at the ...                none
# 3  PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...                none
# 4  hello ! We have a great 75 square meter apartm...                none
#
#    host_id  host_since  host_response_rate            host_neighbourhood  \
# 0     2827  2008-09-09                75.0                    République
# 1     3631  2008-10-14               100.0                        Alésia
# 2     7903  2009-02-14               100.0  Saint-Paul - Ile Saint-Louis
# 3     2626  2008-08-30               100.0                     Le Marais
# 4    22155  2009-06-18                75.0  Gare du Nord - Gare de I'Est
#
#    host_total_listings_count host_identity_verified neighbourhood_cleansed  \
# 0                        2.0                      t               Entrepôt
# 1                        1.0                      f           Observatoire
# 2                        1.0                      t         Hôtel-de-Ville
# 3                        2.0                      t         Hôtel-de-Ville
# 4                        1.0                      t                  Opéra
#
#    ...        room_type  bathrooms  bedrooms price cleaning_fee  \
# 0  ...  Entire home/apt        2.0       2.0   125           40
# 1  ...  Entire home/apt        1.0       1.0    75           50
# 2  ...  Entire home/apt        1.0       0.0   115           36
# 3  ...  Entire home/apt        1.0       2.0   115           50
# 4  ...  Entire home/apt        1.0       2.0    99           60
#
#    minimum_nights  review_scores_rating  reviews_per_month  full_price  \
# 0               3                   NaN                NaN         165
# 1               3                 100.0               0.29         125
# 2               2                  94.0               1.29         151
# 3              10                  94.0               2.47         165
# 4               3                  96.0               0.06         159
#
#    price_category
# 0      Affordable
# 1      Affordable
# 2      Affordable
# 3      Affordable
# 4      Affordable
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 4️⃣EDA : Exploratory Data Analysis

# %% [markdown]
# #### What is the mean and median price of a listing in Paris  ❓

# %%
paris_df.price.median()
# Out:
# 80.0

# %%
paris_df.price.mean()
# Out:
# 110.86477305703019

# %% [markdown]
# #### How many listings have a cleaning fee ❓

# %%
paris_df.price_category.value_counts()
# Out:
# Affordable    56493
# Expensive      2090
# Name: price_category, dtype: int64

# %% [markdown]
# #### What is the average rating for expensive and affordable listings   ❓

# %%
affordable = paris_df[paris_df.price_category == "Affordable"]
expensive = paris_df[paris_df.price_category == "Expensive"]

# %%
affordable.review_scores_rating.mean()
# Out:
# 92.79593267882188

# %%
expensive.review_scores_rating.mean()
# Out:
# 94.20449077786688

# %% [markdown]
# #### What are the best reviewed listings  (with minimum 3 reviews per months) ❓

# %%
reviewed_listings = paris_df[paris_df['reviews_per_month'] > 3]
reviewed_listings.nlargest(10,'review_scores_rating')
# Out:
#                                                     name  \
# 2802     Paris Tour Eiffel 15e Appartement 2 pièces 50m2
# 4964                  2Pièces Duplex 54m2 +Terrasse 20m2
# 5228   Paris Montmartre : Jolie chambre sur cour fleurie
# 5535                 NOTRE DAME:bright, elegant apt 2 BR
# 5764   Quiet / Bright apt btwn Buttes Chaumont & Jour...
# 10895         Studio lumineux et calme, Paris Belleville
# 11487                                          cosy room
# 11885                Appartement cosy au coeur de Paris.
# 14122                        THE BEST DEAL IN THE MARAIS
# 16386           Appartement 55 m2 en plein coeur Paris !
#
#                                                    space experiences_offered  \
# 2802   Appartement 2 pièces de 50m² avec une petite t...                none
# 4964   Appartement type loft disposant de 2 pièces en...                none
# 5228                                                 NaN                none
# 5535   The space: This apartment is designed to comfo...                none
# 5764   This flat for 3 people, is located in 19th dis...                none
# 10895  Ce studio est pratique, spacieux et calme. Il ...                none
# 11487                                                NaN                none
# 11885  Appartement deux pièces chambre et salon, avec...                none
# 14122  If you want to get the local feeling of living...                none
# 16386  Logement spacieux avec balcon dans bel immeubl...                none
#
#         host_id  host_since  host_response_rate            host_neighbourhood  \
# 2802    6667881  2013-05-31                 0.0   Tour Eiffel - Champ de Mars
# 4964   12421039  2014-02-20               100.0  Buttes-Chaumont - Belleville
# 5228   13430813  2014-03-23                80.0                    Montmartre
# 5535    1801963  2012-02-24               100.0   Notre Dame - Ile de La Cité
# 5764   15087229  2014-05-04                 0.0  Buttes-Chaumont - Belleville
# 10895  29382043  2015-03-15                80.0                    République
# 11487  31590660  2015-04-20               100.0  Père Lachaise - Ménilmontant
# 11885  15301422  2014-05-09               100.0  Buttes-Chaumont - Belleville
# 14122   5815201  2013-04-07               100.0            III Arrondissement
# 16386   7852785  2013-07-31               100.0              X Arrondissement
#
#        host_total_listings_count host_identity_verified  \
# 2802                         1.0                      f
# 4964                         1.0                      f
# 5228                         1.0                      t
# 5535                         1.0                      f
# 5764                         1.0                      f
# 10895                        1.0                      t
# 11487                        3.0                      f
# 11885                        1.0                      t
# 14122                        1.0                      t
# 16386                        1.0                      t
#
#       neighbourhood_cleansed  ...        room_type  bathrooms  bedrooms price  \
# 2802               Vaugirard  ...  Entire home/apt        1.0       1.0    90
# 4964         Buttes-Chaumont  ...  Entire home/apt        1.0       1.0    95
# 5228       Buttes-Montmartre  ...     Private room        1.0       1.0    60
# 5535          Hôtel-de-Ville  ...  Entire home/apt        1.0       2.0   300
# 5764         Buttes-Chaumont  ...  Entire home/apt        1.0       1.0    80
# 10895               Entrepôt  ...  Entire home/apt        1.0       0.0    60
# 11487           Ménilmontant  ...     Private room        1.5       1.0    40
# 11885        Buttes-Chaumont  ...  Entire home/apt        1.0       1.0    80
# 14122                 Temple  ...  Entire home/apt        1.0       1.0    90
# 16386               Entrepôt  ...  Entire home/apt        1.0       1.0    95
#
#       cleaning_fee  minimum_nights  review_scores_rating  reviews_per_month  \
# 2802             0               2                 100.0               3.13
# 4964             0               2                 100.0               4.03
# 5228             5               1                 100.0               3.70
# 5535           110               5                 100.0               3.16
# 5764            60               2                 100.0               3.59
# 10895           20               3                 100.0               3.05
# 11487           15               1                 100.0               3.56
# 11885            0               2                 100.0               6.00
# 14122           40               1                 100.0               3.43
# 16386            0               3                 100.0               3.33
#
#        full_price  price_category
# 2802           90      Affordable
# 4964           95      Affordable
# 5228           65      Affordable
# 5535          410      Affordable
# 5764          140      Affordable
# 10895          80      Affordable
# 11487          55      Affordable
# 11885          80      Affordable
# 14122         130      Affordable
# 16386          95      Affordable
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Visualize Data

# %% [markdown]
# #### What are arrondissement with most listings ❓

# %%
plt.figure(figsize=(15, 8))
#Let's get the dataframe that we want to plot 
arr = paris_df.zipcode.value_counts()

#Let's plot it 
arr.plot(kind='bar')

# %% [markdown]
# That's not very nice... We have too many bars !

# %%
#Select only 10 arrondissement with most listings
arr = paris_df.zipcode.value_counts().head(10)
arr.plot(kind='bar')

# %% [markdown]
# That's still not so nice ! Let's make it bigger !

# %%
plt.figure(figsize=(15, 8))
arr.plot(kind='bar')

# %% [markdown]
# #### What is the share of expensive listings for arr. with most listings ❓

# %%
# Let's set the size right away
plt.figure(figsize=(15, 8))

# countplot with a secondary dimension 
sns.countplot(data=paris_df,x="zipcode",hue="price_category")

# %% [markdown]
# We got the same problem ... but now the way to fix it is by using the **order** parameter of the countplot method

# %%
my_order = paris_df.zipcode.value_counts().head(10).index
sns.countplot(data=paris_df,x="zipcode",hue="price_category",order=my_order)

# %% [markdown]
# #### [Distribution] What is the distribution of listings' price  ❓

# %%
#Set the size
plt.figure(figsize=(15, 8))

#plot
sns.distplot(affordable['price'])

# %% [markdown]
# #### Violin Plot

# %% [markdown]
# #### What is the price distribution for each arrondissement ❓

# %%
#set the size
plt.figure(figsize=(15, 8))

#Set an order
order = paris_df.zipcode.value_counts().head(10).index

#plot
sns.violinplot(data=affordable, x="zipcode", y="price", order=order)

# %% [markdown]
# ##### Let's see the geography of listings

# %%
paris_df.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(15,8))

# %% [markdown]
# Why is everything Black ?

# %%
affordable.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(25,12))

# %% [markdown]
# ### 5️⃣ Exporting and sharing

# %%
#affordable listing to csv 
affordable.to_csv("affordable_listing.csv", sep=";", encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7702572cbc66> in <module>
#       1 #affordable listing to csv
# ----> 2 affordable.to_csv("affordable_listing.csv", sep=";", encoding="utf-8-sig")
#
# NameError: name 'affordable' is not defined

# %% [markdown]
# **Now you just need to save your notebook as an html file and it's sharable with anyone**
